# %%
# !pip install -U huggingface_hub
# !huggingface-cli download Qwen/Qwen2.5-0.5B-Instruct-GGUF qwen2.5-0.5b-instruct-q8_0.gguf --local-dir . --local-dir-use-symlinks False
# Out:
# Requirement already satisfied: huggingface_hub in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (0.30.2)
# Requirement already satisfied: filelock in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from huggingface_hub) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from requests->huggingface_hub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/prasun/Desktop/ADHYAYAN_MITRA/.venv/lib/python3.12/site-packages (from requests->huggingface_hub) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%huggingface-cli` not found.

# %%
from langchain_community.llms import LlamaCpp

llm = LlamaCpp(
    model_path="../qwen2.5-0.5b-instruct-q8_0.gguf",  # Path to your downloaded GGUF file
    temperature=0.0,  # Set as needed
    n_ctx=32768,       # Context window, adjust as needed
    max_tokens=8192,   # Max tokens for the response
    n_batch = 64,
    seed = 42,
    n_gpu_layers=0,   # 0 for CPU-only inference
    verbose=False  
)
response = llm.invoke("What is the capital of France?")
print(response)
# Out:
#  The capital of France is Paris.
#
# To elaborate:
#
# 1. Paris, the capital city of France, is located in the center of the country.
#
# 2. It's situated on the banks of the Seine river, which flows through the heart of Paris.
#
# 3. The city has a population of approximately 1.5 million people (as of 2023).
#
# 4. Paris is known for its rich history, beautiful architecture, and vibrant culture.
#
# Therefore, Paris is indeed the capital of France.

# %%
llm
# Out:
# LlamaCpp(verbose=False, client=<llama_cpp.llama.Llama object at 0x764149954230>, model_path='../qwen2.5-0.5b-instruct-q8_0.gguf', n_ctx=32768, n_batch=64, n_gpu_layers=0, max_tokens=8192, temperature=0.0, model_kwargs={})

# %%
"llama_cpp" in str(llm.client )
# Out:
# True

# %%
# %pip install --upgrade --quiet  langchain-huggingface text-generation transformers google-search-results numexpr langchainhub sentencepiece jinja2 bitsandbytes accelerate
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 45.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.8 MB/s eta 0:00:00
#   Building wheel for google-search-results (setup.py) ... done

# %%
from langchain_huggingface.llms import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "Qwen/Qwen2.5-0.5B-Instruct-GPTQ-Int8" #GPU required
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=8192)
hf = HuggingFacePipeline(pipeline=pipe)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

chain = prompt | hf.bind(skip_prompt=False)

question = "What is electroencephalography?"

print(chain.invoke({"question": question}))
# Out:
# Question: What is electroencephalography?
#
# Answer: Let's think step by step. Electroencephalography (EEG) is a diagnostic tool that uses electrodes placed on the scalp to measure electrical activity in the brain. This can help identify abnormalities in brain function, such as epilepsy or other neurological conditions. The process involves placing electrodes on the scalp and connecting them to a device called an EEG machine, which measures the electrical signals generated by the brain. The data collected from these electrodes can then be analyzed using specialized software to identify patterns of brain activity that may indicate a particular condition. While EEG has been used for many years, it has recently become more widely available due to advances in technology and improved accuracy in measuring brain activity.

# %%
chain = prompt | hf.bind(skip_prompt=True)

question = "What is electroencephalography?"

print(chain.invoke({"question": question}))
# Out:
#  First, we need to understand what electroencephalography (EEG) is. EEG is a form of brain imaging that measures electrical activity in the brain using electrodes placed on the scalp. This method has been used for many years and is still widely used today.
#
# Now, let's consider what an electroencephalogram does. An EEG records the electrical activity of the brain during a single thought or mental state. It can show patterns of activity such as spikes and waves that occur in different areas of the brain.
#
# So, to answer the question "What is electroencephalography?", it is essentially a type of brain imaging that uses electrodes placed on the scalp to measure electrical activity in the brain. The goal of EEG is to provide information about the structure and function of the brain, which can be useful for diagnosing and treating various neurological conditions.
